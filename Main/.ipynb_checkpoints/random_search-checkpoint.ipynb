# %%
import numpy as np
import random
# Run the fitness 
from oct2py import Oct2Py
from multiprocessing.pool import ThreadPool 
# Run multiple Zs as different processes
from multiprocessing import Pool
# to save the progress of the algorithms
import csv
from datetime import datetime
from os import mkdir

# %%
# -------- range of the variables ----------
V_S = 7.0                   # service speed [kn]
range_D     = [0.5, 0.8]
range_AEdAO = [0.3, 1.05]
range_PdD   = [0.5, 1.4]
range_Z     = [2, 7]

# Define the lower and upper bounds for each variable
lower_bounds = [range_D[0], range_AEdAO[0], range_PdD[0]]
upper_bounds = [range_D[1], range_AEdAO[1], range_PdD[1]]

# %%
MAX_ITERATION = 128 # number of iterations

NUM_PARALLEL = 4    # number of evaluations done in parallel

# %%
save_file = False
save_in_same_dir = False

if save_file:    
    if save_in_same_dir:
        # create main_date dir
        now = datetime.now()
        main_dir_name = 'main_' + now.strftime("%Y_%m_%d_%H_%M")
        try:
            mkdir(main_dir_name)
        except: pass

# %%
def append_to_file(filename, row):
    with open(filename, 'a', newline='') as file:
        writer = csv.writer(file)
        writer.writerow(row)
    
def append_to_file_order(filename, D='', AEdAO='', PdD='', Z='', P_B='', n='', fitness='', i=''):
    row = [D, AEdAO, PdD, Z, P_B, n, fitness, i]
    append_to_file(filename, row)
    
def create_file(text):
    filename = dir_name+'/' + text +'.csv'
    with open(filename, 'w', newline='') as file:
        writer = csv.writer(file)
        header = ["D = propeller diameter [m]", 
                  "AEdAO = expanded area ratio", 
                  "PdD = pitch ratio", 
                  "Z = propeller's number of blades", 
                  "P_B = power brake", 
                  "n = Propeller angular speed [rpm]", 
                  "fitness", 
                  "i = thread pool id"]
        writer.writerow(header) 
    return filename

def create_dir(text):
    if save_in_same_dir:
        dir_name = './' + main_dir_name + '/' + text
    else:
        now = datetime.now()
        dir_name = './' + text +'_'+ now.strftime("%Y_%m_%d_%H_%M")
    try:
        mkdir(dir_name)
    except: pass
    return dir_name

# %%
def run_octave_evaluation(V_S,D,Z,AEdAO,PdD):
    P_B, n = [0, 0]
    with Oct2Py() as octave:
        octave.warning ("off", "Octave:data-file-in-path");
        octave.addpath('./allCodesOctave');
        P_B, n = octave.F_LabH2(V_S,D,Z,AEdAO,PdD, nout=2)
    return [P_B, n]

# %%
def evaluate_solution(x, i=None):
    D     = x[0]
    AEdAO = x[1]
    PdD   = x[2]
    # verify that the values are in range
    penalty = -1000
    if (D > range_D[1] or D < range_D[0]):
        print("out","_D_:",D,"Z:",Z,"AEdAO:",AEdAO,"PdD:",PdD)
        return penalty
    if (AEdAO > range_AEdAO[1] or AEdAO < range_AEdAO[0]):
        print("out","D:",D,"Z:",Z,"_AEdAO_:",AEdAO,"PdD:",PdD)
        return penalty
    if (PdD > range_PdD[1] or PdD < range_PdD[0]):
        print("out","D:",D,"Z:",Z,"AEdAO:",AEdAO,"_PdD_:",PdD)
        return penalty

    P_B, n = run_octave_evaluation(V_S,D,Z,AEdAO,PdD)
    # to get the minimal P_B 
    # the solvers use the max value as best fitness
    fit_value = 0
    if (P_B == 0 or n == 0):
        fit_value = penalty
    else:
        fit_value = -P_B
    
#     print("D:",D,"Z:",Z,"AEdAO:",AEdAO,"PdD:",PdD, "fitness:",fit_value)
    if save_file:
        append_to_file(filename, [D, AEdAO, PdD, Z, P_B, n, fit_value, i])

    return fit_value

# use evaluate_solution as the fitness function
fit_func = evaluate_solution

# %%
def run(z):
    global Z
    Z = z
    # create history list
    n_batches_to_save = 3
    history = np.zeros((MAX_ITERATION // NUM_PARALLEL) // n_batches_to_save)
    # start best value
    best_fitness = float('-inf')
    best_x       = [-1, -1, -1]
    
    # execute for MAX_ITERATION in batches of NUM_PARALLEL
    for i in range(MAX_ITERATION // NUM_PARALLEL):
        fitness_list = np.zeros(NUM_PARALLEL)
        # create a list of params for evaluation
        x_list       = [[] for _ in range(NUM_PARALLEL)] 
        for j in range(NUM_PARALLEL):
            # generate random values for params
            x =  [
                    random.uniform(range_D[0],     range_D[1]),
                    random.uniform(range_AEdAO[0], range_AEdAO[1]),
                    random.uniform(range_PdD[0],   range_PdD[1])
                  ]
            x_list[j] = x
        # evaluate the list of params in parralel
        with ThreadPool() as pool:
            id_x = [(k, x_list[k]) for k in range(NUM_PARALLEL)]
            fitness_wrapper = (lambda k, x: [k, fit_func(x)] )
            for result in pool.starmap(fitness_wrapper, id_x):
                k, fitness = result
                fitness_list[k] = fitness
        # go through the results and update the best result
        for k in range(NUM_PARALLEL):
            x = x_list[k]
            fitness = fitness_list[k]  
            # if not failed, update best
            #  fitness is negative, so the best is the max
            if (fitness != 0) and fitness > best_fitness:
                best_fitness = fitness
                best_x       = x
        # end of batch
        if (i % n_batches_to_save) == 0:
            print('iteration:', i, 'best fitness:', best_fitness)
            counter = i // n_batches_to_save
            history[counter] = best_fitness
            if save_file:
                append_to_file_order(filename, "fitness at iteration", i, fitness=best_fitness)
    # return
    return [Z, best_x, best_fitness, history]

# %%
# results[0] = [Z, (D, AEdAO, PdD), fitness, history]
def get_best_result(results):
    # get result with best fitness
    best_result = max(results, key=(lambda x: x[2]))
    
    Z             =  best_result[0]
    D, AEdAO, PdD =  best_result[1]
    P_B           = -best_result[2]
    print("D:",D,"Z:",Z,"AEdAO:",AEdAO,"PdD:",PdD)
    print("P_B:",P_B)
    
    return best_result

# %% [markdown]
# parallel

# %%
if save_file:
    global dir_name
    dir_name = create_dir('random')
    
results = []
with Pool() as pool:
    for result in pool.map(run, range(range_Z[0],range_Z[1]+1)):
        results.append(result)

# %%
# sort by Z
results.sort(key=(lambda r: r[0]))

print("Best result cmaes")
best_result = get_best_result(results)
# Out:
# Best result cmaes
# D: 0.7895597885572455 Z: 5 AEdAO: 0.6168952413899103 PdD: 0.6241257728460603
# P_B: 82.41458839358792

# %%
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipykernel_1925385/3462037968.py in <module>
#       1 labels    = [str(r[0])     for r in results]
# ----> 2 fitnesses = np.array([r[3] for r in results])
#       3 # create image with Z's as labels
#       4 create_history_fig(labels, fitnesses)
#
# /tmp/ipykernel_1925385/3462037968.py in <listcomp>(.0)
#       1 labels    = [str(r[0])     for r in results]
# ----> 2 fitnesses = np.array([r[3] for r in results])
#       3 # create image with Z's as labels
#       4 create_history_fig(labels, fitnesses)
#
# IndexError: list index out of range

# %% [markdown]
# OPENAI-ES parallel

# %%
if save_file:
    global dir_name
    dir_name = create_dir('openaies')

solver = openaies
results_openaies = []
with Pool() as pool:
    solver_zs = [(solver, z) for z in range(range_Z[0],range_Z[1]+1)]
    for result in pool.starmap(solver_for_Z, solver_zs):
        results_openaies.append(result)
# Out:
# Z: 2 fitness at iteration 1 -83.71732718276915
# local optimum discovered by solver:
#  [0.8        0.3        0.86500124]
# fitness score at this local optimum: -83.71732718276915
# Z: 2 Best Solution: [0.8        0.3        0.86500124] with fitness: -83.71732718276915
# Z: 5 fitness at iteration 1 -83.11654528793244
# local optimum discovered by solver:
#  [0.8        0.3        0.86500124]
# fitness score at this local optimum: -83.11654528793244
# Z:Z: 5  Best Solution:3  fitness at iteration[0.8        0.3        0.86500124]  with fitness:1  -82.87335166905244-83.11654528793244
#
# local optimum discovered by solver:
#  [0.8        0.3        0.86500124]
# fitness score at this local optimum: -82.87335166905244
# Z: 3 Best Solution: [0.8        0.3        0.86500124] with fitness: -82.87335166905244
# Z: 4 fitness at iteration 1 -82.7351705089447
# local optimum discovered by solver:
#  [0.8        0.3        0.86500124]
# fitness score at this local optimum: -82.7351705089447
# ...

# %%
# sort by Z
results_openaies.sort(key=(lambda r: r[0]))

print("Best result openai-es")
best_result_openaies = get_best_result(results_openaies)
# Out:
# Best result openai-es
# D: 0.8 Z: 4 AEdAO: 0.3 PdD: 0.8650012387098835
# P_B: 82.7351705089447

# %%
labels             = [str(r[0])     for r in results_openaies]
fitnesses_openaies = np.array([r[3] for r in results_openaies])
# create image with Z's as labels
create_history_fig(labels, fitnesses_openaies)

# %% [markdown]
# Compare cmaes and openai-es

# %%
best_history_openaies = best_result_openaies[3]
best_history_cmaes    = best_result_cmaes[3]

create_history_fig(['OPENAI-ES', 'CMAES'], [best_history_openaies, best_history_cmaes])

# %%
best_Z_openaies = best_result_openaies[0]
best_Z_cmaes    = best_result_cmaes[0]

plt.figure(figsize=(16,8), dpi=150)

lines = []
colors = ['blue', 'orange']
for r in results_openaies:
    z       = r[0]
    history = r[3]
    history = np.negative(history)
    line, = plt.plot(history, linewidth=1.0, color=colors[0], linestyle="solid" if z == best_Z_openaies else '--', label='OPENAI-ES')
    lines.append(line)
for r in results_cmaes:
    z       = r[0]
    history = r[3]
    history = np.negative(history)
    line, = plt.plot(history, linewidth=1.0, color=colors[1], linestyle="solid" if z == best_Z_cmaes else '--', label='CMAES')
    lines.append(line)

    
plt.legend(handles=lines)

plt.xlabel('generation')
plt.ylabel('fitness')

plt.show()

# %% [markdown]
# ## Greedy Algorithm

# %%
bigest_range = max([r[0]+r[1] for r in [range_D, range_AEdAO, range_PdD]])
STARTING_SIGMA = (bigest_range / NUM_SEGMENTS) / 2
print(STARTING_SIGMA)

# NUM_SEGMENTS = 2
# NUM_ITERATIONS = MAX_ITERATION - 1
print(NUM_ITERATIONS * (2**3) + (NUM_SEGMENTS**3) )
# Out:
# 0.31666666666666665
# 27

# %%
def greedy_to_Z(z):
    global Z
    Z = z
    
    if save_file:
        global filename
        filename = create_file(str(Z))
    
    segmented_D     = np.linspace(range_D[0],     range_D[1],     NUM_SEGMENTS)
    segmented_AEdAO = np.linspace(range_AEdAO[0], range_AEdAO[1], NUM_SEGMENTS)
    segmented_PdD   = np.linspace(range_PdD[0],   range_PdD[1],   NUM_SEGMENTS)

    history = np.zeros(NUM_ITERATIONS+1)
    # generate all permutations
    solutions = []
    for d in segmented_D:
        for a in segmented_AEdAO:
            for p in segmented_PdD:
                solutions.append( (d,a,p) )
    # parallel run of fitness evaluation
    fitness_list = np.zeros(len(solutions))
    with ThreadPool() as pool:
        id_solutions = [(i, solutions[i]) for i in range(len(solutions))]
        for result in pool.starmap(fit_func_parallel_wrapper, id_solutions):
            i, fitness = result
            fitness_list[i] = fitness
    # get best solution
    best_fitness = max(fitness_list)
    best_solution_index = np.where(fitness_list == best_fitness)[0][0]
    best_solution = solutions[best_solution_index]
    # save in history
    history[0] = best_fitness
    if save_file:
        append_to_file_order(filename, "fitness at iteration", '0', fitness=best_fitness)
    # 
    sigma = STARTING_SIGMA
    for iteration in range(NUM_ITERATIONS):
        D, AEdAO, PdD = best_solution
        # create values around the best solution
        Ds     = [D     - sigma, D     + sigma]
        AEdAOs = [AEdAO - sigma, AEdAO + sigma]
        PdDs   = [PdD   - sigma, PdD   + sigma]
        # clip values to be inside the range
        Ds     = np.clip(Ds,     range_D[0],     range_D[1])
        AEdAOs = np.clip(AEdAOs, range_AEdAO[0], range_AEdAO[1])
        PdDs   = np.clip(PdDs,   range_PdD[0],   range_PdD[1])
        # generate all permutations
        solutions = []
        for d in Ds:
            for a in AEdAOs:
                for p in PdDs:
                    solutions.append( (d,a,p) )
        # parallel run of fitness evaluation
        fitness_list = np.zeros(len(solutions))
        with ThreadPool() as pool:
            id_solutions = [(i, solutions[i]) for i in range(len(solutions))]
            for result in pool.starmap(fit_func_parallel_wrapper, id_solutions):
                i, fitness = result
                fitness_list[i] = fitness
        # get best solution
        new_best_fitness = max(fitness_list)
        # if new best fitness is better than the previous one, change to new best fitness
        if new_best_fitness > best_fitness:
            best_fitness = new_best_fitness
            # update best solution
            best_solution_index = np.where(fitness_list == best_fitness)[0][0]
            best_solution = solutions[best_solution_index]
        # save best fitness in history 
        history[iteration+1] = best_fitness
        # update sigma for the next iteration
        print('Z:',Z ,"iteration:", iteration+1, ' best finess', best_fitness)
        if save_file:
            append_to_file(filename, ["fitness at iteration", iteration+1,'','','','', best_fitness])
        sigma = sigma / 2
    print('Z:',Z, 'best', best_solution, 'with fit:', best_fitness)
    return [Z, best_solution, best_fitness, history]

# %%
if save_file:
    global dir_name
    dir_name = create_dir('greedy')
    
results_greedy = []
with Pool() as pool:
    for result in pool.map(greedy_to_Z, range(range_Z[0],range_Z[1]+1)):
        results_greedy.append(result)
# Out:
# Z: 5 best (0.8, 0.3, 0.95) with fit: -84.92735814490393
# Z: 4 best (0.8, 0.3, 0.5) with fit: -82.94111624353914
# Z:Z: 3 2  bestbest  (0.8, 0.3, 0.5)(0.8, 0.3, 0.95) with fit: with fit: -80.51058808084673 -87.04035618951274
#
# Z: 7 best (0.8, 0.675, 0.95) with fit: -83.7855949495112
# Z: 6 best (0.8, 0.675, 0.95) with fit: -83.96942643864858

# %%
# results_greedy = [Z, best_solution, best_fitness, history]
# sort by Z
results_greedy.sort(key=(lambda x: x[0]))

# get result with best fitness
best_result_greedy = max(results_greedy, key=(lambda x: x[2]))

# print(best_result_greedy)
Z = best_result_greedy[0]
D, AEdAO, PdD = best_result_greedy[1]
P_B = -best_result_greedy[2]
print("D:",D,"Z:",Z,"AEdAO:",AEdAO,"PdD:",PdD)
print("P_B:",P_B)
# Out:
# D: 0.8 Z: 3 AEdAO: 0.3 PdD: 0.5
# P_B: 80.51058808084673

# %%
histories_greedy = np.array([r[3] for r in results_greedy])
labels = [str(r[0]) for r in results_greedy]
create_history_fig(labels, histories_greedy)

# %% [markdown]
# ## Save

# %%
def save_best_result(result, solver_name):
    # create the csv file with the headers
    global filename
    filename = create_file('best_results_' + solver_name)
    Z             = result[0]
    D, AEdAO, PdD = result[1]
    fitness       = result[2]
    history       = result[3]
    append_to_file_order(filename, D=D, AEdAO=AEdAO, PdD=PdD, Z=Z, fitness=fitness)
    append_to_file(['history'])
    append_to_file(history)
        
if save_file:
    save_best_result(best_result_cmaes, 'cmaes')
    save_best_result(best_result_openaies, 'openaies')
#     save_best_result(best_result_greedy, 'greedy')
# Out:
# [7, array([0.78991985, 0.50443523, 1.05898221]), -86.6379717939757, array([-86.63797179])]

# %% [markdown]
# ## Compare

# %%
# get the history of the best result
best_history_openaies = best_result_openaies[3]
best_history_cmaes    = best_result_cmaes[3]
best_history_greedy   = best_result_greedy[3]
# best_history_greedy    = histories_greedy[7-2]
# make fitness positive
best_history_openaies = np.negative(best_history_openaies)
best_history_cmaes    = np.negative(best_history_cmaes)
best_history_greedy   = np.negative(best_history_greedy)

# Create a new figure
plt.figure(figsize=(16,8), dpi=150)

line_openaies, = plt.plot(best_history_openaies, linewidth=1.0, label='OPENAI-ES')
line_cmaes,    = plt.plot(best_history_cmaes,    linewidth=1.0, label='CMAES')
line_greedy,   = plt.plot(best_history_greedy,   linewidth=1.0, label='Greedy')

plt.legend(handles=[line_openaies, line_cmaes, line_greedy])

plt.xlabel('generation')
plt.ylabel('fitness')

plt.show()

# %%
fig, ax = plt.subplots()

labels = ['OPENAI-ES', 'CMAES', 'Greedy']
counts = [best_result_openaies[2], best_result_cmaes[2], best_result_greedy[2]]
counts = np.negative(counts)
bar_colors = ['tab:blue', 'tab:orange', 'tab:green']

ax.bar(labels, counts , color=bar_colors)

ax.set_ylabel('fitness')
ax.set_xlabel('algorithm')

# plt.ylim([80, 90])
plt.ylim([min(counts)-1, max(counts)+1])

plt.show()

# %%
print("Best of all")
best_of_all = max([best_result_openaies, best_result_cmaes, best_result_greedy], key=(lambda r: r[2]))

Z             =  best_of_all[0]
D, AEdAO, PdD =  best_of_all[1]
P_B           = -best_of_all[2]
print("D:",D,"Z:",Z,"AEdAO:",AEdAO,"PdD:",PdD)
print("P_B:",P_B)
# Out:
# Best of all
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1004798/1971288842.py in <module>
#       1 print("Best of all")
# ----> 2 best_of_all = max([best_result_openaies, best_result_cmaes, best_result_greedy], key=(lambda r: r[2]))
#       3
#       4 Z             =  best_of_all[0]
#       5 D, AEdAO, PdD =  best_of_all[1]
#
# NameError: name 'best_result_openaies' is not defined

# %%
best_Z_openaies = best_result_openaies[0]
best_Z_cmaes    = best_result_cmaes[0]
best_Z_greedy   = best_result_greedy[0]

# Create a new figure
plt.figure(figsize=(16,8), dpi=150)

lines = []
colors = ['blue', 'orange', 'green']
for r in results_openaies:
    z = r[0]
    history = r[3]
    history = np.negative(history)
    line, = plt.plot(history, linewidth=1.0, color=colors[0], linestyle="solid" if z == best_Z_openaies else '--', label='OPENAI-ES')
    lines.append(line)
for r in results_cmaes:
    z = r[0]
    history = r[3]
    history = np.negative(history)
    line, = plt.plot(history, linewidth=1.0, color=colors[1], linestyle="solid" if z == best_Z_cmaes else '--', label='CMAES')
    lines.append(line)
for r in results_greedy:
    z = r[0]
    history = r[3]
    history = np.negative(history)
    line, = plt.plot(history, linewidth=1.0, color=colors[2], linestyle="solid" if z == best_Z_greedy else '--', label='Greedy')
    lines.append(line)
    
plt.legend(handles=lines)

plt.xlabel('generation')
plt.ylabel('fitness')

plt.show()

# %%
def show_img_for_Z(Z_):
    # get the history of Z
    z_history_openaies = [r[3] for r in results_openaies if r[0] == Z_][0]
    z_history_cmaes    = [r[3] for r in results_cmaes    if r[0] == Z_][0]
    z_history_greedy   = [r[3] for r in results_greedy   if r[0] == Z_][0]
    # make fitness positive
    z_history_openaies = np.negative(z_history_openaies)
    z_history_cmaes    = np.negative(z_history_cmaes)
    z_history_greedy   = np.negative(z_history_greedy)

    # Create a new figure
    plt.figure(figsize=(16,8), dpi=150)

    line_openaies, = plt.plot(z_history_openaies, linewidth=1.0, label=str(Z_)+' OPENAI-ES')
    line_cmaes,    = plt.plot(z_history_cmaes,    linewidth=1.0, label=str(Z_)+' CMAES')  
    line_greedy,   = plt.plot(z_history_greedy,   linewidth=1.0, label=str(Z_)+' Greedy')

    plt.legend(handles=[line_openaies, line_cmaes, line_greedy])

    plt.xlabel('generation')
    plt.ylabel('fitness')

    plt.show()
    
for z in range(range_Z[0], range_Z[1]+1):
    show_img_for_Z(z)

# %%
print('Best of all')
Z             =  best_of_all[0]
D, AEdAO, PdD =  best_of_all[1]
P_B           = -best_of_all[2]
# print("D:",D,"Z:",Z,"AEdAO:",AEdAO,"PdD:",PdD)
print("P_B:",P_B)

# %%
D     = 0.800
Z     = 5
AEdAO = 0.6053
PdD   = 0.6946

P_B, n = run_octave_evaluation(V_S, D, Z, AEdAO, PdD)
cristopher_P_B = P_B
cristopher_P_B
# Out:
# 81.36300651084139
